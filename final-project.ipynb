# %% [markdown]
# **This notebook is an exercise in the [Data Visualization](https://www.kaggle.com/learn/data-visualization) course.  You can reference the tutorial at [this link](https://www.kaggle.com/alexisbcook/final-project).**
#
# ---

# %% [markdown]
# Now it's time for you to demonstrate your new skills with a project of your own!
#
# In this exercise, you will work with a dataset of your choosing.  Once you've selected a dataset, you'll design and create your own plot to tell interesting stories behind the data!
#
# ## Setup
#
# Run the next cell to import and configure the Python libraries that you need to complete the exercise.

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# The questions below will give you feedback on your work. Run the following cell to set up the feedback system.

# %% [markdown]
# ## Step 1: Attach a dataset to the notebook
#
# Begin by selecting a CSV dataset from [Kaggle Datasets](https://www.kaggle.com/datasets).  If you're unsure how to do this, please revisit the instructions in the previous tutorial.
#
# Once you have selected a dataset, click on the **[+ Add data]** option in the top right corner.  This will generate a pop-up window that you can use to search for your chosen dataset.
#
# ![ex6_search_dataset](https://storage.googleapis.com/kaggle-media/learn/images/cIIWPUS.png)
#
# Once you have found the dataset, click on the **[Add]** button to attach it to the notebook.  You can check that it was successful by looking at the **Data** dropdown menu to the right of the notebook -- look for an **input** folder containing a subfolder that matches the name of the dataset.
#
# <center>
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/nMYc1Nu.png" width=30%><br/>
# </center>
#
# You can click on the carat to the left of the name of the dataset to double-check that it contains a CSV file.  For instance, the image below shows that the example dataset contains two CSV files: (1) **dc-wikia-data.csv**, and (2) **marvel-wikia-data.csv**.
#
# <center>
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/B4sJkVA.png" width=30%><br/>
# </center>
#
# Once you've uploaded a dataset with a CSV file, run the code cell below **without changes** to receive credit for your work!

# %% [markdown]
# ## Step 2: Specify the filepath
#
# Now that the dataset is attached to the notebook, you can find its filepath.  To do this, begin by clicking on the CSV file you'd like to use.  This will open the CSV file in a tab below the notebook.  You can find the filepath towards the top of this new tab.
#
# ![ex6_filepath](https://storage.googleapis.com/kaggle-media/learn/images/fgXQV47.png)
#
# After you find the filepath corresponding to your dataset, fill it in as the value for `my_filepath` in the code cell below, and run the code cell to check that you've provided a valid filepath.  For instance, in the case of this example dataset, we would set
# ```
# my_filepath = "../input/fivethirtyeight-comic-characters-dataset/dc-wikia-data.csv"
# ```
# Note that **you must enclose the filepath in quotation marks**; otherwise, the code will return an error.
#
# Once you've entered the filepath, you can close the tab below the notebook by clicking on the **[X]** at the top of the tab.

# %%
# Fill in the line below: Specify the path of the CSV file to read
my_filepath = '/kaggle/input/steam-games-dataset/games_may2024_cleaned.csv'
# Out:
# Correct:

# %% [markdown]
# ## Step 3: Load the data
#
# Use the next code cell to load your data file into `my_data`.  Use the filepath that you specified in the previous step.

# %%
# Fill in the line below: Read the file into a variable my_data
my_data = pd.read_csv(my_filepath, index_col='AppID')
# Out:
# Correct:

# %% [markdown]
# **_After the code cell above is marked correct_**, run the code cell below without changes to view the first five rows of the data.

# %%
# Print the first five rows of the data
my_data.head()
# Out:
#                                    name release_date  required_age  price  \
# AppID
# 730                    Counter-Strike 2   2012-08-21             0   0.00
# 578080              PUBG: BATTLEGROUNDS   2017-12-21             0   0.00
# 570                              Dota 2   2013-07-09             0   0.00
# 271590               Grand Theft Auto V   2015-04-13            17   0.00
# 359550  Tom Clancy's Rainbow Six® Siege   2015-12-01            17  19.99
#
#         dlc_count                               detailed_description  \
# AppID
# 730             1  For over two decades, Counter-Strike has offer...
# 578080          0  LAND, LOOT, SURVIVE! Play PUBG: BATTLEGROUNDS ...
# 570             2  The most-played game on Steam. Every day, mill...
# 271590          1  When a young street hustler, a retired bank ro...
# 359550          9  Edition Comparison Ultimate Edition The Tom Cl...
#
#                                            about_the_game  \
# AppID
# 730     For over two decades, Counter-Strike has offer...
# 578080  LAND, LOOT, SURVIVE! Play PUBG: BATTLEGROUNDS ...
# 570     The most-played game on Steam. Every day, mill...
# 271590  When a young street hustler, a retired bank ro...
# 359550  “One of the best first-person shooters ever ma...
#
#                                         short_description  \
# AppID
# 730     For over two decades, Counter-Strike has offer...
# 578080  Play PUBG: BATTLEGROUNDS for free. Land on str...
# 570     Every day, millions of players worldwide enter...
# 271590  Grand Theft Auto V for PC offers players the o...
# 359550  Tom Clancy's Rainbow Six® Siege is an elite, t...
#
#                                                   reviews  \
# AppID
# 730                                                   NaN
# 578080                                                NaN
# 570     “A modern multiplayer masterpiece.” 9.5/10 – D...
# 271590                                                NaN
# 359550                                                NaN
#
#                                              header_image  ...  \
# AppID                                                      ...
# 730     https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 578080  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 570     https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 271590  https://shared.akamai.steamstatic.com/store_it...  ...
# 359550  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
#
#        average_playtime_forever average_playtime_2weeks  \
# AppID
# 730                       29018                     753
# 578080                        0                       0
# 570                       35557                    1327
# 271590                    12898                     590
# 359550                    16213                     578
#
#        median_playtime_forever  median_playtime_2weeks  peak_ccu  \
# AppID
# 730                       6078                     352   1362469
# 578080                       0                       0    590582
# 570                       1163                     977    668192
# 271590                    6910                     235    133571
# 359550                    3016                     331     68162
#
#                                                      tags  pct_pos_total  \
# AppID
# 730     {'FPS': 90076, 'Shooter': 64786, 'Multiplayer'...             87
# 578080  {'Survival': 14611, 'Shooter': 12477, 'Battle ...             58
# 570     {'Free to Play': 59559, 'MOBA': 19966, 'Multip...             81
# 271590  {'Open World': 31998, 'Action': 23177, 'Multip...             87
# 359550  {'FPS': 9689, 'PvP': 9073, 'e-sports': 9026, '...             85
#
#        num_reviews_total  pct_pos_recent  num_reviews_recent
# AppID
# 730              8071426              80               56072
# 578080           2365012              68               19517
# 570              2247365              71               23832
# 271590           1643791              92               16181
# 359550           1091695              77               10566
#
# [5 rows x 45 columns]

# %%
df = my_data.nlargest(10, 'peak_ccu')

map_name = {'Counter-Strike 2': 'CS2', 'PUBG: BATTLEGROUNDS': 'PUBG', 'NARAKA: BLADEPOINT': 'NARAKA',
       'Apex Legends™': 'Apex', 'Grand Theft Auto V': 'GTA5'}

df['name'] = df['name'].map(map_name).fillna(df['name'])

df
# Out:
#                    name release_date  required_age  price  dlc_count  \
# AppID
# 730                 CS2   2012-08-21             0   0.00          1
# 570              Dota 2   2013-07-09             0   0.00          2
# 578080             PUBG   2017-12-21             0   0.00          0
# 1203220          NARAKA   2021-08-11             0   0.00          4
# 1172470            Apex   2020-11-04             0   0.00          0
# 271590             GTA5   2015-04-13            17   0.00          1
# 252490             Rust   2018-02-08            17  39.99          4
# 413150   Stardew Valley   2016-02-26             0  14.99          1
# 1085660       Destiny 2   2019-10-01             0   0.00         14
# 377160        Fallout 4   2015-11-09            17  19.99          9
#
#                                       detailed_description  \
# AppID
# 730      For over two decades, Counter-Strike has offer...
# 570      The most-played game on Steam. Every day, mill...
# 578080   LAND, LOOT, SURVIVE! Play PUBG: BATTLEGROUNDS ...
# 1203220  FREE TO PLAY NOW About the Game Dynamic, fast-...
# 1172470  Apex Legends: Upheaval About the Game Conquer ...
# 271590   When a young street hustler, a retired bank ro...
# 252490   The only aim in Rust is to survive. Everything...
# 413150   Stardew Valley is an open-ended country-life R...
# 1085660  Expansion Open Access Period until 10am PT on ...
# 377160   Creation Kit / Review Highlights About the Gam...
#
#                                             about_the_game  \
# AppID
# 730      For over two decades, Counter-Strike has offer...
# 570      The most-played game on Steam. Every day, mill...
# 578080   LAND, LOOT, SURVIVE! Play PUBG: BATTLEGROUNDS ...
# 1203220  Dynamic, fast-paced and ever shifting; battle ...
# 1172470  Conquer with character in Apex Legends, a free...
# 271590   When a young street hustler, a retired bank ro...
# 252490   The only aim in Rust is to survive. Everything...
# 413150   Stardew Valley is an open-ended country-life R...
# 1085660  Expansion Open Access Period until 10am PT on ...
# 377160   Bethesda Game Studios, the award-winning creat...
#
#                                          short_description  \
# AppID
# 730      For over two decades, Counter-Strike has offer...
# 570      Every day, millions of players worldwide enter...
# 578080   Play PUBG: BATTLEGROUNDS for free. Land on str...
# 1203220  Dive into the legends of the Far East in NARAK...
# 1172470  Apex Legends is the award-winning, free-to-pla...
# 271590   Grand Theft Auto V for PC offers players the o...
# 252490   The only aim in Rust is to survive. Everything...
# 413150   You've inherited your grandfather's old farm p...
# 1085660  Destiny 2 is an action MMO with a single evolv...
# 377160   Bethesda Game Studios, the award-winning creat...
#
#                                                    reviews  \
# AppID
# 730                                                    NaN
# 570      “A modern multiplayer masterpiece.” 9.5/10 – D...
# 578080                                                 NaN
# 1203220  “Naraka Bladepoint is proof that the last-figh...
# 1172470  “The champion of Battle Royales.” 9/10 – GameS...
# 271590                                                 NaN
# 252490   “Rust is one of the cruelest games on Steam, a...
# 413150   “Far more than just a farming game, this one-m...
# 1085660                                                NaN
# 377160   “An Open-World Masterpiece” 5/5 – Nerdist “Bes...
#
#                                               header_image  ...  \
# AppID                                                       ...
# 730      https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 570      https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 578080   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 1203220  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 1172470  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 271590   https://shared.akamai.steamstatic.com/store_it...  ...
# 252490   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 413150   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 1085660  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 377160   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
#
#         average_playtime_forever average_playtime_2weeks  \
# AppID
# 730                        29018                     753
# 570                        35557                    1327
# 578080                         0                       0
# 1203220                        0                       0
# 1172470                     9323                     686
# 271590                     12898                     590
# 252490                     16499                    1486
# 413150                      4190                     607
# 1085660                    10120                    1411
# 377160                      6200                     978
#
#         median_playtime_forever  median_playtime_2weeks  peak_ccu  \
# AppID
# 730                        6078                     352   1362469
# 570                        1163                     977    668192
# 578080                        0                       0    590582
# 1203220                       0                       0    269356
# 1172470                     639                     310    169567
# 271590                     6910                     235    133571
# 252490                     2513                     633    122371
# 413150                     1787                     337     91798
# 1085660                     353                     742     85768
# 377160                     1863                     486     82089
#
#                                                       tags  pct_pos_total  \
# AppID
# 730      {'FPS': 90076, 'Shooter': 64786, 'Multiplayer'...             87
# 570      {'Free to Play': 59559, 'MOBA': 19966, 'Multip...             81
# 578080   {'Survival': 14611, 'Shooter': 12477, 'Battle ...             58
# 1203220  {'Battle Royale': 983, 'Multiplayer': 949, 'Ma...             75
# 1172470  {'Free to Play': 1964, 'Battle Royale': 1354, ...             77
# 271590   {'Open World': 31998, 'Action': 23177, 'Multip...             87
# 252490   {'Survival': 17867, 'Crafting': 11333, 'Multip...             87
# 413150   {'Farming Sim': 7032, 'Pixel Graphics': 6609, ...             98
# 1085660  {'Free to Play': 3284, 'Open World': 2900, 'FP...             80
# 377160   {'Open World': 9641, 'Post-apocalyptic': 8545,...             83
#
#         num_reviews_total  pct_pos_recent  num_reviews_recent
# AppID
# 730               8071426              80               56072
# 570               2247365              71               23832
# 578080            2365012              68               19517
# 1203220            224410              74                6381
# 1172470            829738              59               11412
# 271590            1643791              92               16181
# 252490             874762              86                9347
# 413150             602714              98               14182
# 1085660            595362              73                4932
# 377160             240413              79               10025
#
# [10 rows x 45 columns]

# %% [markdown]
# ## Step 4: Visualize the data
#
# Use the next code cell to create a figure that tells a story behind your dataset.  You can use any chart type (_line chart, bar chart, heatmap, etc_) of your choosing!

# %%
# Create a plot

plt.figure(figsize=(12, 4))
sns.barplot(x=df.name, y=df['peak_ccu'])
# Out:
# Correct:
